# %%
import pandas as pd

# %%
df = pd.concat(pd.read_excel("C:/Users/pankaj.k_dataflowgro/Downloads/New latest list of Delhi updated June 2020.xlsx", sheet_name=None), ignore_index=True)

# %%
df
# Out:
#      Sr.\nNo.                              Name of the Hospitals  \
# 0         1.0                             Action Cancer Hospital
# 1         2.0  Adiva Super- Speciality Care\nEmpanelment with...
# 2         3.0  Batra   Hospital and       Medical Research Ce...
# 3         4.0                                  Bhagwati Hospital
# 4         5.0                                    Bansal Hospital
# ..        ...                                                ...
# 744       NaN                                                NaN
# 745       4.0                                                NaN
# 746       NaN                                                NaN
# 747       5.0                                                NaN
# 748       NaN                                                NaN
#
#                                     Address & Tel. No.  \
# 0    A-4. Paschim Vihar, New Delhi -63. Tel. No. 01...
# 1    C-1/C, Green Park Extension, New Delhi. Tel. N...
# ...

# %%
df.to_excel("C:\\Users\\pankaj.k_dataflowgro\\Desktop\\info.xlsx", index=False)

# %%
help()
